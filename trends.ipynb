# %%
import pandas as pd

history = pd.read_csv('data/unique_video_browsing_history_full_tiktok_data.csv')
likes = pd.read_csv('data/likes_full_tiktok_data.csv')
favorites = pd.read_csv('data/favorite_videos_full_tiktok_data.csv')

# %%
sound_trend = pd.read_csv('backend/sound_trend.csv')

# %%
# check if each item from sound_trend is in history and how many times
sound_trend['count'] = 0
for index, row in sound_trend.iterrows():
    sound_trend.loc[index, 'count'] = len(history[history['Sound Link'] == row['Sound Link']])

# %%
sound_trend
# Out:
#                                            Sound Link  count
# 0   www.tiktok.com/music/Collide-sped-up-714984552...     12
# 1   www.tiktok.com/music/cupid-twin-version-720475...     30
# 2   www.tiktok.com/music/Her-Way-Sped-Up-712365469...      1
# 3   www.tiktok.com/music/Favorite-Song-Sped-Up-720...      0
# 4   www.tiktok.com/music/Boy's-a-liar-Pt-2-7189713...      0
# 5   www.tiktok.com/music/Bounce-When-She-Walk-By-O...      0
# 6   www.tiktok.com/music/Peaches-Eggplants-feat-21...      0
# 7   www.tiktok.com/music/In-Ha-Mood-71853320951897...      0
# 8     www.tiktok.com/music/Makeba-7234525541365418757     37
# 9   www.tiktok.com/music/Cruel-Summer-721141478814...    143
# 10  www.tiktok.com/music/If-We-Ever-Broke-Up-71833...      8
# 11  www.tiktok.com/music/What-It-Is-Solo-Version-7...      4
# 12  www.tiktok.com/music/%E0%B8%A1%E0%B8%AD%E0%B8%...      0
# 13  www.tiktok.com/music/La-Bebe-Remix-72106369372...      0
# 14      www.tiktok.com/music/LALA-7212832308926089218      0
# 15  www.tiktok.com/music/girls-like-me-don't-cry-s...     21
# 16       www.tiktok.com/music/TQG-7200995956416841729      3
# 17  www.tiktok.com/music/What-Was-I-Made-For-From-...    134

# %%
tiktok_trend = pd.read_csv('backend/tiktok_trend.csv')

# %%
# drop history rows where the description is nan
history_description = history.copy()
history_description = history_description.dropna(subset=['Description'])

tiktok_trend['count'] = 0
tiktok_trend['matching_indexes'] = None

for index, row in tiktok_trend.iterrows():
    mask = history_description['Description'].str.lower().str.contains(str.lower(row['Trends']))
    matching_indexes = history_description[mask].index.tolist()
    
    tiktok_trend.at[index, 'count'] = len(matching_indexes)
    tiktok_trend.at[index, 'matching_indexes'] = matching_indexes if matching_indexes else []

# %%
tiktok_trend
# Out:
#                         Trends  count  \
# 0                  Girl Dinner     10
# 1                 Wes Anderson      8
# 2                     Red Flag     18
# 3                   Beige Flag      0
# 4   Altered my brain chemistry      7
# 5          thank you to my man      9
# 6                  canon event     13
# 7              look at my son       0
# 8                      zepotha      3
# 9        paying the cheese tax      0
# 10              where's my dad      0
# 11                Taylor Swift    726
# 12                     Beyoncé      6
# 13           Sabrina Carpenter     19
# 14                    Paramore      2
# 15                roman empire     13
# 16               grimace shake      0
# 17          planet of the bass      0
# 18                    rat girl      2
# 19                   girl math      6
# 20                      barbie    975
# 21                Barbenheimer      5
# 22                     booktok     22
# 23                        cozy     52
#
#                                      matching_indexes
# 0   [4078, 4084, 4226, 9764, 11883, 29771, 30670, ...
# 1   [45830, 47475, 47793, 48160, 49542, 51245, 512...
# 2   [150, 990, 1778, 1978, 3603, 4013, 4028, 28291...
# 3                                                  []
# 4   [75737, 76857, 77424, 78838, 81090, 84399, 85976]
# 5   [5014, 6480, 16316, 16318, 25869, 26341, 37146...
# 6   [8612, 8614, 9866, 9940, 9942, 11083, 17539, 1...
# 7                                                  []
# 8                               [23025, 23498, 23500]
# 9                                                  []
# 10                                                 []
# 11  [9, 57, 141, 178, 294, 310, 325, 411, 512, 522...
# 12         [10515, 11969, 15362, 30008, 67242, 70730]
# 13  [7713, 7715, 7770, 9328, 10077, 13524, 14264, ...
# 14                                     [37221, 40673]
# 15  [38, 795, 856, 1097, 1109, 1212, 1231, 3088, 3...
# 16                                                 []
# 17                                                 []
# 18                                       [6285, 6287]
# 19           [7998, 8318, 14124, 21523, 87037, 87039]
# 20  [275, 1147, 1183, 1847, 1848, 3375, 3613, 4098...
# 21                [36298, 36842, 38515, 40095, 84956]
# 22  [306, 307, 950, 1430, 5969, 8302, 8304, 8306, ...
# 23  [9, 1631, 2077, 3130, 3135, 3137, 3483, 5523, ...

# %%
#turn trends into hashtags by removing spaces and special characters like "'"
tiktok_trend['Hashtags'] = tiktok_trend['Trends'].str.replace(' ', '')
tiktok_trend['Hashtags'] = tiktok_trend['Hashtags'].str.replace("'", '')
tiktok_trend['Hashtags'] = '#' + tiktok_trend['Hashtags'].str.lower()
tiktok_trend
# Out:
#                         Trends  count  \
# 0                  Girl Dinner     10
# 1                 Wes Anderson      8
# 2                     Red Flag     18
# 3                   Beige Flag      0
# 4   Altered my brain chemistry      7
# 5          thank you to my man      9
# 6                  canon event     13
# 7              look at my son       0
# 8                      zepotha      3
# 9        paying the cheese tax      0
# 10              where's my dad      0
# 11                Taylor Swift    726
# 12                     Beyoncé      6
# 13           Sabrina Carpenter     19
# 14                    Paramore      2
# 15                roman empire     13
# 16               grimace shake      0
# 17          planet of the bass      0
# 18                    rat girl      2
# 19                   girl math      6
# 20                      barbie    975
# 21                Barbenheimer      5
# 22                     booktok     22
# 23                        cozy     52
#
#                                      matching_indexes  \
# 0   [4078, 4084, 4226, 9764, 11883, 29771, 30670, ...
# 1   [45830, 47475, 47793, 48160, 49542, 51245, 512...
# 2   [150, 990, 1778, 1978, 3603, 4013, 4028, 28291...
# 3                                                  []
# 4   [75737, 76857, 77424, 78838, 81090, 84399, 85976]
# 5   [5014, 6480, 16316, 16318, 25869, 26341, 37146...
# 6   [8612, 8614, 9866, 9940, 9942, 11083, 17539, 1...
# 7                                                  []
# 8                               [23025, 23498, 23500]
# 9                                                  []
# 10                                                 []
# 11  [9, 57, 141, 178, 294, 310, 325, 411, 512, 522...
# 12         [10515, 11969, 15362, 30008, 67242, 70730]
# 13  [7713, 7715, 7770, 9328, 10077, 13524, 14264, ...
# 14                                     [37221, 40673]
# 15  [38, 795, 856, 1097, 1109, 1212, 1231, 3088, 3...
# 16                                                 []
# 17                                                 []
# 18                                       [6285, 6287]
# 19           [7998, 8318, 14124, 21523, 87037, 87039]
# 20  [275, 1147, 1183, 1847, 1848, 3375, 3613, 4098...
# 21                [36298, 36842, 38515, 40095, 84956]
# 22  [306, 307, 950, 1430, 5969, 8302, 8304, 8306, ...
# 23  [9, 1631, 2077, 3130, 3135, 3137, 3483, 5523, ...
#
#                     Hashtags
# 0                #girldinner
# 1               #wesanderson
# 2                   #redflag
# 3                 #beigeflag
# 4   #alteredmybrainchemistry
# 5           #thankyoutomyman
# 6                #canonevent
# 7               #lookatmyson
# 8                   #zepotha
# 9        #payingthecheesetax
# 10              #wheresmydad
# 11              #taylorswift
# 12                  #beyoncé
# 13         #sabrinacarpenter
# 14                 #paramore
# 15              #romanempire
# 16             #grimaceshake
# 17          #planetofthebass
# 18                  #ratgirl
# 19                 #girlmath
# 20                   #barbie
# 21             #barbenheimer
# 22                  #booktok
# 23                     #cozy

# %%
history_hashtags = history.copy()
history_hashtags = history_hashtags.dropna(subset=['Hashtags'])

for index, row in tiktok_trend.iterrows():
    mask = history_hashtags['Hashtags'].str.lower().str.contains(str.lower(row['Hashtags']))
    matching_indexes = history_hashtags[mask].index.tolist()

    tiktok_trend.at[index, 'matching_indexes'] = list(set(tiktok_trend.at[index, 'matching_indexes'] + matching_indexes))
   
    
    tiktok_trend.at[index, 'count'] = len(tiktok_trend.at[index, 'matching_indexes']) if tiktok_trend.at[index, 'matching_indexes'] else tiktok_trend.at[index, 'count']

# %%
tiktok_trend
# Out:
#                         Trends  count  \
# 0                  Girl Dinner     35
# 1                 Wes Anderson     14
# 2                     Red Flag     42
# 3                   Beige Flag     21
# 4   Altered my brain chemistry      7
# 5          thank you to my man     12
# 6                  canon event     31
# 7              look at my son       0
# 8                      zepotha      9
# 9        paying the cheese tax      0
# 10              where's my dad      1
# 11                Taylor Swift   9680
# 12                     Beyoncé     13
# 13           Sabrina Carpenter    154
# 14                    Paramore      9
# 15                roman empire     30
# 16               grimace shake      7
# 17          planet of the bass      0
# 18                    rat girl      2
# 19                   girl math     43
# 20                      barbie   2672
# 21                Barbenheimer     76
# 22                     booktok   1066
# 23                        cozy    173
#
#                                      matching_indexes  \
# 0   [2688, 4226, 2307, 3204, 23177, 8459, 21392, 1...
# 1   [48160, 73248, 49542, 45830, 50790, 51245, 512...
# 2   [60930, 28291, 50568, 3721, 59656, 22413, 6798...
# 3   [62597, 60690, 51731, 65942, 51095, 54316, 524...
# 4   [81090, 84399, 77424, 78838, 85976, 75737, 76857]
# 5   [38688, 26341, 8071, 25869, 26477, 38686, 6480...
# 6   [17539, 54533, 9866, 17546, 27658, 26899, 4469...
# 7                                                  []
# 8   [23842, 23498, 23500, 23180, 23468, 23470, 230...
# 9                                                  []
# 10                                             [1020]
# 11  [65536, 1, 65538, 65541, 32776, 9, 11, 13, 20,...
# 12  [81344, 11969, 15362, 51489, 65732, 67242, 707...
# 13  [35332, 53258, 25613, 17429, 44565, 87063, 225...
# 14  [40673, 39396, 37221, 41388, 61133, 5615, 4136...
# 15  [5122, 6534, 5896, 3468, 4108, 3088, 4241, 206...
# 16  [41377, 45409, 13861, 43335, 44392, 34680, 43228]
# 17                                                 []
# 18                                       [6285, 6287]
# 19  [87040, 10113, 87041, 3587, 3204, 87042, 87043...
# 20  [40968, 32780, 40977, 40979, 40987, 40989, 819...
# 21  [34945, 34947, 29188, 36611, 33030, 42763, 367...
# 22  [4099, 22532, 63492, 43015, 88071, 81929, 8807...
# 23  [6659, 45571, 57859, 20486, 9, 81930, 84490, 6...
#
#                     Hashtags
# 0                #girldinner
# 1               #wesanderson
# 2                   #redflag
# 3                 #beigeflag
# 4   #alteredmybrainchemistry
# 5           #thankyoutomyman
# 6                #canonevent
# 7               #lookatmyson
# 8                   #zepotha
# 9        #payingthecheesetax
# 10              #wheresmydad
# 11              #taylorswift
# 12                  #beyoncé
# 13         #sabrinacarpenter
# 14                 #paramore
# 15              #romanempire
# 16             #grimaceshake
# 17          #planetofthebass
# 18                  #ratgirl
# 19                 #girlmath
# 20                   #barbie
# 21             #barbenheimer
# 22                  #booktok
# 23                     #cozy
